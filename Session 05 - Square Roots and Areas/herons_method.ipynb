# %% [markdown]
# **Define a function `sqrt(s)` that implements Heron's Method**

# %%
# Cell 1
def sqrt(s):
    x = s / 2
    while x**2 - s > 1e-10:
        x = (s / x + x) / 2
    return x

# %% [markdown]
# **Use `sqrt(x)` to calculate $\sqrt{168923.74}$**

# %%
# Cell 2
print(sqrt(168923.74))
