# %% [markdown]
# **Import the scipy.special module to gain access to the `factorial` function**

# %%
# Cell 1
import numpy as np
import scipy.special

# %% [markdown]
# **Create an integer array where $0\le x < 20$**

# %%
# Cell 2

# %% [markdown]
# **Set $z=0+\pi i$**

# %%
# Cell 3

# %% [markdown]
# **Create array $n=z^x$**

# %%
# Cell 4

# %% [markdown]
# **Create array $d=x!$**

# %%
# Cell 5

# %% [markdown]
# **Divide every term in array $n$ by the corresponding term in array $d$**

# %%
# Cell 6

# %% [markdown]
# **Calculate $e^z=\sum\limits_{x=0}^{\infty}\frac{z^x}{x!}$ where $z=\pi i$**

# %%
# Cell 7
