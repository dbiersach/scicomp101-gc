# %% [markdown]
# **Import common packages**

# %%
# Cell 1
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Create the $\theta$ array where $0\le\theta\le 10\pi$**

# %%
# Cell 2

# %% [markdown]
# **Plot the Archimedean spiral using a polar projection**

# %%
# Cell 3
