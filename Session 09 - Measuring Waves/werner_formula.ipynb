# %% [markdown]
# **Import needed packages**

# %%
# Cell 1
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Span domain $-3\pi\le x\le 3\pi$ over $101$ equally spaced intervals** \
# Notice that $x=0$ is included because we have an *odd* number of intervals

# %%
# Cell 2

# %% [markdown]
# **Define the two amplitudes $a$ and $b$ using <u>tuple</u> unpacking**

# %%
# Cell 3

# %% [markdown]
# **Create the dependent variable arrays** \
# $f_1=\sin{a\ x}$̐\
# $f_2=\sin{b\ x}$\
# $f_3=f_1(x)*f_2(x)$

# %%
# Cell 4

# %% [markdown]
# **Implement Werner's Product-to-Sum for $f_4\ $**

# %%
# Cell 5

# %% [markdown]
# **Plot the four functions**\
# $f_4(x)$ should be drawn as a grey dotted line with closed circle markers

# %%
# Cell 6
