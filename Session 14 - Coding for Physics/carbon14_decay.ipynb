# %% [markdown]
# **Import needed packages/modules**

# %%
# Cell 1
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Set the simulation duration**
# 1. $t_f$ is the <u>final</u> time (in years)
# 2. $t_s$ is the number of `time steps`
# 3. $dt$ is the time difference (delta time) between successive estimates

# %%
# Cell 2
tf =
ts =
dt = tf / ts  # delta time

# %% [markdown]
# **Create two numpy `arrays` to hold independent and dependent variable values**
# 1. $t$ holds the time stamps (elapsed time) at each time step
# 2. $n$ holds the number of nuclei (as a percent of initial value) at each time step
#
# So we need as many elements in each array as there are total time steps\
# We can initialize each element to zero in both arrays

# %%
# Cell 3
t = np.zeros(ts)
n = np.zeros(ts)

# %% [markdown]
# **Set the initial conditions of this simulation**
# 1. The initial concentration (at time step 0) of the nuclei is 100%
# 2. The half-life $\tau$ of ${C}_{14}$ is $5,730$ years

# %%
# Cell 4
n[0] =
tau =

# %% [markdown]
# **User Euler's Method (forward in time) to estimate the decay curve of Carbon-14**
# 1. $i$ is current the interval # (the time step #)
# 2. The <u>next</u> time interval $t[i+1]$ value will be the current time $t[i]+dt$
# 3. The <u>next</u> nuclei count $n[i+1]$ value will be the current nuclei count $\large n[i]-\frac{n[t]}{\tau}dt$

# %%
# Cell 5
for i in range(ts - 1):
    t[i + 1] =
    n[i + 1] =

# %% [markdown]
# **Plot the decay curve of Carbon-14**

# %%
# Cell 6
plt.plot(t, n)
plt.title("Carbon-14 Decay")
plt.xlabel("Time (years)")
plt.ylabel("% Concentration")
plt.show()
