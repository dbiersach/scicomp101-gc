# %% [markdown]
# **Import needed packages/modules**

# %%
# Cell 1
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Set simulation duration**

# %%
# Cell 2
tf =
ts =
dt = tf / ts  # delta time

# %% [markdown]
# **Initialze arrays to hold the independent and four (4) dependent variables**
# 1. $t(i)=$ Time at each interval $i$
# 2. $m(i)=$ Rocket mass (kg) at each interval $i$
# 3. $a(i)=$ Rocket acceleration (m/s^2) at each interval $i$
# 4. $v(i)=$ Rocket velocity (m) at each interval $i$
# 5. $s(i)=$ Total distance (m) flown by the rocket up to each interval $i$

# %%
# Cell 3
t = np.zeros(ts)
m = np.zeros(ts)
a = np.zeros(ts)
v = np.zeros(ts)
s = np.zeros(ts)

# %% [markdown]
# **Set initial conditions as specified in problem statement**

# %%
# Cell 4
m[0] =
a[0] =

# %% [markdown]
# **Calculate the values at each interval (time step)**
# 1. $\large t_{i+1}=t_i+dt$
# 2. $\large m_{i+1}=m_i+e^{-t_i}+1$ (formula given in description)
# 3. $\large a_{i+1}=a_i+e^{\frac{-t_i}{2}}$ (formula given in description)
# 4. $\large v_{i+1}=v_i+m_i\times a_i\times dt$ (Galileo's Kinematics)
# 5. $\large s_{i+1}=s_i+v_i\times dt$ (Galileo's Kinematics)

# %%
# Cell 5
for i in range(ts - 1):
    t[i + 1] =
    m[i + 1] =
    a[i + 1] =
    v[i + 1] =
    s[i + 1] =

# %% [markdown]
# **Display the total distance the rocket flies after 5 seconds**

# %%
# Cell 6
print(f"s = {s[-1]:.4f} m")

# %% [markdown]
# **Plot the trajectory of the rocket for the first 5 seconds**

# %%
# Cell 7
plt.plot(t, m, label="mass (kg)")
plt.plot(t, a, label="accel (m/s^2)")
plt.plot(t, v, label="velocity (m/s)")
plt.plot(t, s, label="distance (m)")
plt.title("Rocket Propulsion")
plt.xlabel("Seconds")
plt.ylabel("Amplitude")
plt.legend(loc="right")
plt.grid()
plt.show()
