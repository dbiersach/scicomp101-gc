# %% [markdown]
# **Import necessary packages/modules**

# %%
# Cell 1
import json
from pathlib import Path

from google.colab import drive

# %% [markdown]
# **Connect this notebook to your Google Drive**

# %%
# Cell 2
drive.mount("/content/gdrive", force_remount=True)
notebook_path = Path("/content/gdrive/MyDrive/SciComp101-GC")
notebook_path = notebook_path / Path("Session 13 - Using Data Files")

# %% [markdown]
# **Create dictionary of Uranium isotope data**
# 1. Notice the value of each key is itself another dictionary
# 2. The half-life values are in units of seconds
# 3. Python natively understands scientific notation

# %%
# Cell 3
uranium_isotopes = {
    "Uranium 233": {
        "atomic_mass": "233.03963 u",
        "neutrons": 141,
        "half-life": 5.015e12,
    },
    "Uranium 234": {
        "atomic_mass": "234.04095 u",
        "neutrons": 142,
        "half-life": 7.758e12,
    },
    "Uranium 235": {
        "atomic_mass": "235.04393 u",
        "neutrons": 143,
        "half-life": 2.208e16,
    },
    "Uranium 236": {
        "atomic_mass": "236.04557 u",
        "neutrons": 144,
        "half-life": 7.379e14,
    },
    "Uranium 237": {
        "atomic_mass": "237.04873 u",
        "neutrons": 145,
        "half-life": 583200,
    },
    "Uranium 238": {
        "atomic_mass": "238.05079 u",
        "neutrons": 146,
        "half-life": 1.407e17,
    },
}

# %% [markdown]
# **Write the dictionary to a JSON-formatted text (ASCII) file**\
# The file will appear in your Google Drive in the same folder as this notebook

# %%
# Cell 4
file_name = "uranium_isotopes.json"
file_path = notebook_path / file_name

with Path.open(file_path, "w", encoding="ascii") as file_out:
    json.dump(uranium_isotopes, file_out, indent=4)

print(f'The file "{file_name}" was successfully created!')
