# %% [markdown]
# **Define a function to display all the factors of a quadratic polynomial**

# %%
# Cell 1
def factor_quadratic(J, K, L):
    print("Given the quadratic:")
    print(f"{J}x^2 + {K}x + {L} = 0")
    print("The factors are:")

    # Add your code here

# %% [markdown]
# **Factor $115425x^2+3254121x+379020$**

# %%
# Cell 2
factor_quadratic(115425, 3254121, 379020)

# %% [markdown]
# **Factor $115425x^2+3254121x+379021$**

# %%
# Cell 3
factor_quadratic(115425, 3254121, 379021)
